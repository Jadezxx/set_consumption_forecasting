# %%
import numpy as np
import pandas as pd

# %%
filename = 'C:/program2/tensorflow/data/day_data_nov.csv'

# %%
data = pd.read_csv(filename)
data
# Out:
#       Unnamed: 0    0
# 0              0  2.0
# 1              1  2.0
# 2              2  2.0
# 3              3  2.0
# 4              4  2.0
# 5              5  2.0
# 6              6  2.0
# 7              7  2.0
# 8              8  2.0
# 9              9  2.0
# 10            10  2.0
# 11            11  2.0
# 12            12  2.0
# 13            13  2.0
# 14            14  2.0
# 15            15  2.0
# 16            16  2.0
# 17            17  2.0
# 18            18  2.0
# 19            19  2.0
# 20            20  2.0
# 21            21  2.0
# 22            22  2.0
# 23            23  2.0
# 24            24  2.0
# 25            25  2.0
# 26            26  2.0
# 27            27  2.0
# 28            28  2.0
# 29            29  2.0
# ...          ...  ...
# 4290        4290  1.0
# 4291        4291  1.0
# 4292        4292  1.0
# 4293        4293  1.0
# 4294        4294  1.0
# 4295        4295  1.0
# 4296        4296  1.0
# 4297        4297  1.0
# 4298        4298  1.0
# ...
