# %%
import pandas as pd

# %%
data1 = pd.read_csv('set_consumption_nov.csv')
data2 = pd.read_csv('set_consumption_dec.csv')

# %%
data1
# Out:
#       Unnamed: 0       155       272       273       276       277       389  \
# 0     1383235200  0.101565  1.828174  0.533217  0.829945  0.073230  1.650435
# 1     1383235800  0.086957  1.565217  0.456522  0.836692  0.073826  1.413043
# 2     1383236400  0.093913  1.690435  0.493043  0.796207  0.070254  1.526087
# 3     1383237000  0.089391  1.609043  0.469304  0.789460  0.069658  1.452609
# 4     1383237600  0.088696  1.596522  0.465652  0.769217  0.067872  1.441304
# 5     1383238200  0.082783  1.490087  0.434609  0.769217  0.067872  1.345217
# 6     1383238800  0.081391  1.465043  0.427304  0.769217  0.067872  1.322609
# 7     1383239400  0.082087  1.477565  0.430957  0.745601  0.065788  1.333913
# 8     1383240000  0.071652  1.289739  0.376174  0.742227  0.065491  1.164348
# 9     1383240600  0.058783  1.058087  0.308609  0.772591  0.068170  0.955217
# 10    1383241200  0.082783  1.490087  0.434609  0.742227  0.065491  1.345217
# ...

# %%
data2
# Out:
#       Unnamed: 0       155       272       273       276       277       389  \
# 0     1385827200  0.099826  1.796870  0.524087  0.742227  0.065491  1.622174
# 1     1385827800  0.100870  1.815652  0.529565  0.721985  0.063705  1.639130
# 2     1385828400  0.103304  1.859478  0.542348  0.732106  0.064598  1.678696
# 3     1385829000  0.094261  1.696696  0.494870  0.688247  0.060728  1.531739
# 4     1385829600  0.096000  1.728000  0.504000  0.688247  0.060728  1.560000
# 5     1385830200  0.098435  1.771826  0.516783  0.668004  0.058942  1.599565
# 6     1385830800  0.095304  1.715478  0.500348  0.678126  0.059835  1.548696
# 7     1385831400  0.091130  1.640348  0.478435  0.651136  0.057453  1.480870
# 8     1385832000  0.096348  1.734261  0.505826  0.661257  0.058346  1.565652
# 9     1385832600  0.090435  1.627826  0.474783  0.661257  0.058346  1.469565
# 10    1385833200  0.090435  1.627826  0.474783  0.641014  0.056560  1.469565
# ...

# %%
column = data1.columns
column
# Out:
# Index(['Unnamed: 0', '155', '272', '273', '276', '277', '389', '390', '393',
#        '506',
#        ...
#        '10867', '10868', '10980', '10981', '10982', '10983', '10984', '11097',
#        '11098', '11099'],
#       dtype='object', length=2021)

# %%
data3 = data1.append(data2,ignore_index=True)
data3
# Out:
#       Unnamed: 0       155       272       273       276       277       389  \
# 0     1383235200  0.101565  1.828174  0.533217  0.829945  0.073230  1.650435
# 1     1383235800  0.086957  1.565217  0.456522  0.836692  0.073826  1.413043
# 2     1383236400  0.093913  1.690435  0.493043  0.796207  0.070254  1.526087
# 3     1383237000  0.089391  1.609043  0.469304  0.789460  0.069658  1.452609
# 4     1383237600  0.088696  1.596522  0.465652  0.769217  0.067872  1.441304
# 5     1383238200  0.082783  1.490087  0.434609  0.769217  0.067872  1.345217
# 6     1383238800  0.081391  1.465043  0.427304  0.769217  0.067872  1.322609
# 7     1383239400  0.082087  1.477565  0.430957  0.745601  0.065788  1.333913
# 8     1383240000  0.071652  1.289739  0.376174  0.742227  0.065491  1.164348
# 9     1383240600  0.058783  1.058087  0.308609  0.772591  0.068170  0.955217
# 10    1383241200  0.082783  1.490087  0.434609  0.742227  0.065491  1.345217
# ...

# %%
data3.to_csv('set_consumption.csv')

# %%
data4 = pd.read_csv('set_consumption.csv')
data4
# Out:
#       Unnamed: 0  Unnamed: 0.1       155       272       273       276  \
# 0              0    1383235200  0.101565  1.828174  0.533217  0.829945
# 1              1    1383235800  0.086957  1.565217  0.456522  0.836692
# 2              2    1383236400  0.093913  1.690435  0.493043  0.796207
# 3              3    1383237000  0.089391  1.609043  0.469304  0.789460
# 4              4    1383237600  0.088696  1.596522  0.465652  0.769217
# 5              5    1383238200  0.082783  1.490087  0.434609  0.769217
# 6              6    1383238800  0.081391  1.465043  0.427304  0.769217
# 7              7    1383239400  0.082087  1.477565  0.430957  0.745601
# 8              8    1383240000  0.071652  1.289739  0.376174  0.742227
# 9              9    1383240600  0.058783  1.058087  0.308609  0.772591
# 10            10    1383241200  0.082783  1.490087  0.434609  0.742227
# 11            11    1383241800  0.076870  1.383652  0.403565  0.732106
# ...

# %%
set1 = data4['272']

# %%
set1
# Out:
# 0       1.828174
# 1       1.565217
# 2       1.690435
# 3       1.609043
# 4       1.596522
# 5       1.490087
# 6       1.465043
# 7       1.477565
# 8       1.289739
# 9       1.058087
# 10      1.490087
# 11      1.383652
# 12      1.565217
# 13      1.333565
# 14      1.308522
# 15      1.383652
# 16      1.352348
# 17      1.458783
# 18      1.346087
# 19      1.440000
# 20      1.346087
# 21      1.239652
# 22      1.296000
# 23      1.202087
# 24      1.346087
# 25      1.283478
# 26      1.383652
# 27      1.289739
# 28      1.321043
# 29      1.339826
#           ...
# 8754    2.729739
# 8755    2.642087
# 8756    2.679652
# 8757    2.548174
# 8758    2.648348
# 8759    2.673391
# 8760    2.466783
# 8761    2.422956
# 8762    2.422956
# 8763    2.422956
# 8764    2.372870
# 8765    2.379130
# 8766    2.260174
# 8767    2.178783
# 8768    2.178783
# 8769    2.197565
# 8770    2.228869
# 8771    2.109913
# 8772    2.141217
# 8773    2.034783
# 8774    2.034783
# ...

# %%
import matplotlib.pyplot as plt
x = [i for i in range(len(set1))]
fig = plt.figure(figsize = [60,10])
ax = fig.add_subplot(1,1,1)
ax.plot(x,set1)
plt.show()

# %%
import matplotlib.pyplot as plt
x = [i for i in range(len(data4['393']))]
fig = plt.figure(figsize = [60,10])
ax = fig.add_subplot(1,1,1)
ax.plot(x,data4['393'])
plt.show()
