# %%
import pandas as pd

# %%
name = ['线路','时间','电力消耗情况']
f = pd.read_csv('SET-dec-2013.csv',names = name,header = None)
f
# Out:
#                线路                时间      电力消耗情况
# 0       DG1000420  2013-12-01 00:00   36.719997
# 1       DG1000420  2013-12-01 00:10   36.180000
# 2       DG1000420  2013-12-01 00:20   35.639999
# 3       DG1000420  2013-12-01 00:30   34.559998
# 4       DG1000420  2013-12-01 00:40   34.559998
# 5       DG1000420  2013-12-01 00:50   34.019997
# 6       DG1000420  2013-12-01 01:00   32.399998
# 7       DG1000420  2013-12-01 01:10   32.399998
# 8       DG1000420  2013-12-01 01:20   31.859999
# 9       DG1000420  2013-12-01 01:30   30.239998
# 10      DG1000420  2013-12-01 01:40   30.239998
# 11      DG1000420  2013-12-01 01:50   30.239998
# 12      DG1000420  2013-12-01 02:00   31.319998
# 13      DG1000420  2013-12-01 02:10   31.319998
# 14      DG1000420  2013-12-01 02:20   30.239998
# 15      DG1000420  2013-12-01 02:30   30.239998
# 16      DG1000420  2013-12-01 02:40   30.239998
# 17      DG1000420  2013-12-01 02:50   30.239998
# 18      DG1000420  2013-12-01 03:00   30.239998
# ...

# %%
f1 = pd.read_csv('line.csv')
f1
# Out:
#       SQUAREID    LINESET  NR_UBICAZIONI
# 0          155  DG1031221              4
# 1          272  DG1031221             72
# 2          273  DG1031221             21
# 3          276  DG1003117             34
# 4          277  DG1003117              3
# 5          389  DG1031221             65
# 6          390  DG1031221              8
# 7          393  DG1003117             25
# 8          506  DG1031221             12
# 9          507  DG1031221             27
# 10         624  DG1031221              5
# 11         625  DG1031221              6
# 12         626  DG1003117              2
# 13         635  DG1003117              7
# 14         737  DG1031220              9
# 15         738  DG1031220              1
# 16         740  DG1031221              7
# 17         741  DG1031221            355
# 18         742  DG1031221             32
# 19         743  DG1003117             10
# 20         743  DG1031221             74
# 21         752  DG1003117              5
# ...

# %%
f1.loc[f1['SQUAREID'] == 1206]
# Out:
#     SQUAREID    LINESET  NR_UBICAZIONI
# 58      1206  DG1031220              3

# %%
f2 = pd.read_csv('SET-nov-2013.csv',header = None)
f2
# Out:
#                 0                 1          2
# 0       DG1000420  2013-11-01 00:00  37.439999
# 1       DG1000420  2013-11-01 00:10  37.439999
# 2       DG1000420  2013-11-01 00:20  36.000000
# 3       DG1000420  2013-11-01 00:30  35.279999
# 4       DG1000420  2013-11-01 00:40  35.279999
# 5       DG1000420  2013-11-01 00:50  34.199997
# 6       DG1000420  2013-11-01 01:00  35.279999
# 7       DG1000420  2013-11-01 01:10  34.199997
# 8       DG1000420  2013-11-01 01:20  33.119999
# 9       DG1000420  2013-11-01 01:30  34.739998
# 10      DG1000420  2013-11-01 01:40  32.939999
# 11      DG1000420  2013-11-01 01:50  32.399998
# 12      DG1000420  2013-11-01 02:00  32.399998
# 13      DG1000420  2013-11-01 02:10  32.399998
# 14      DG1000420  2013-11-01 02:20  31.859999
# 15      DG1000420  2013-11-01 02:30  32.399998
# 16      DG1000420  2013-11-01 02:40  31.319998
# 17      DG1000420  2013-11-01 02:50  30.959999
# 18      DG1000420  2013-11-01 03:00  32.219997
# ...
