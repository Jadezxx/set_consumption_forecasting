# %%
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np

# %%
file = pd.read_csv('set_consumption_dec.csv')
file
# Out:
#       Unnamed: 0       155       272       273       276       277       389  \
# 0     1385827200  0.099826  1.796870  0.524087  0.742227  0.065491  1.622174
# 1     1385827800  0.100870  1.815652  0.529565  0.721985  0.063705  1.639130
# 2     1385828400  0.103304  1.859478  0.542348  0.732106  0.064598  1.678696
# 3     1385829000  0.094261  1.696696  0.494870  0.688247  0.060728  1.531739
# 4     1385829600  0.096000  1.728000  0.504000  0.688247  0.060728  1.560000
# 5     1385830200  0.098435  1.771826  0.516783  0.668004  0.058942  1.599565
# 6     1385830800  0.095304  1.715478  0.500348  0.678126  0.059835  1.548696
# 7     1385831400  0.091130  1.640348  0.478435  0.651136  0.057453  1.480870
# 8     1385832000  0.096348  1.734261  0.505826  0.661257  0.058346  1.565652
# 9     1385832600  0.090435  1.627826  0.474783  0.661257  0.058346  1.469565
# 10    1385833200  0.090435  1.627826  0.474783  0.641014  0.056560  1.469565
# ...

# %%
#ef plot_id_week(square_id,file):
data_week = file.iloc[1:1009]
y1 = data_week[square_id[10]]
y2 = data_week[square_id[30]]
x =[i for i in range(0, 1008)] 
fig = plt.figure(figsize=(30,10))
ax1 = fig.add_subplot(2,1,1)
ax1.plot(x,y1)
#ax1.title(square_id[10])
#plt.xlabel('time')
#plt.ylabel('set_consumption')
ax1.set_xticks(np.linspace(0,1008,29))
ax1.set_xticklabels(('11-1 0点','11-1 6点','11-1 12点','11-1 18点',
                   '11-2 0点','11-2 6点','11-2 12点','11-2 18点',
                   '11-3 0点','11-3 6点','11-3 12点','11-3 18点',
                   '11-4 0点','11-4 6点','11-4 12点','11-4 18点',
                   '11-5 0点','11-5 6点','11-5 12点','11-5 18点',
                   '11-6 0点','11-6 6点','11-6 12点','11-6 18点',
                   '11-7 0点','11-7 6点','11-7 12点','11-7 18点',
                    '11-8 0点'))

ax2 = fig.add_subplot(2,1,2)
ax2.plot(x,y2)
#ax2.title(str(square_id[30]))
#plt.xlabel('time')
#plt.ylabel('set_consumption')
ax2.set_xticks(np.linspace(0,1008,29))
ax2.set_xticklabels(('11-1 0点','11-1 6点','11-1 12点','11-1 18点',
                   '11-2 0点','11-2 6点','11-2 12点','11-2 18点',
                   '11-3 0点','11-3 6点','11-3 12点','11-3 18点',
                   '11-4 0点','11-4 6点','11-4 12点','11-4 18点',
                   '11-5 0点','11-5 6点','11-5 12点','11-5 18点',
                   '11-6 0点','11-6 6点','11-6 12点','11-6 18点',
                   '11-7 0点','11-7 6点','11-7 12点','11-7 18点',
                   '11-8 0点' ))

plt.savefig('set_consumption.jpg')
plt.show()

# %%
plot_id_week(square_id,file)

# %%
data_week = file.iloc[1:1008]
square_id = data_week.T.index

# %%
square_id
# Out:
# Index(['Unnamed: 0', '155', '272', '273', '276', '277', '389', '390', '393',
#        '506',
#        ...
#        '10867', '10868', '10980', '10981', '10982', '10983', '10984', '11097',
#        '11098', '11099'],
#       dtype='object', length=2021)

# %%
square_id[10]
# Out:
# '507'

# %%
square_id[30]
# Out:
# '868'
