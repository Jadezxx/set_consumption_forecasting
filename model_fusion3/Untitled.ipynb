# %%
import pandas as pd

# %%
data = pd.read_csv('D:/document/gas_healthy/data/score_test.csv')
data = data.drop('Unnamed: 0',1)
data
# Out:
#      siteId  expireScore  setScore  yearcheckScore  stationStateScore  \
# 0       103        24.85     23.80           69.84              70.00
# 1       104         8.25      8.25           40.98               0.00
# 2       101         0.00      0.00           82.19               0.00
# 3       122         0.00      0.00           69.19             100.00
# 4       127         0.00      0.00            0.00               0.00
# 5       130        88.28     64.44            0.00               0.00
# 6       109         0.00      0.00            0.00              98.73
# 7       134         0.00      0.00            0.00             100.00
# 8       126         0.00      0.00           61.97             100.00
# 9       135         0.00      0.00            0.00             100.00
# 10      155         0.00      0.00            0.00             100.00
# 11      142         0.00      0.00            0.00             100.00
# ...

# %%
data.reindex(on = 'siteId')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-e51727a2b336> in <module>()
# ----> 1 data.reindex(on = 'siteId')
#
# D:\anaconda\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     184         @wraps(func)
#     185         def wrapper(*args, **kwargs):
# --> 186             return func(*args, **kwargs)
#     187
#     188         if not PY2:
#
# D:\anaconda\lib\site-packages\pandas\core\frame.py in reindex(self, *args, **kwargs)
#    3561         kwargs.pop('axis', None)
#    3562         kwargs.pop('labels', None)
# -> 3563         return super(DataFrame, self).reindex(**kwargs)
#    3564
#    3565     @Appender(_shared_docs['reindex_axis'] % _shared_doc_kwargs)
#
# D:\anaconda\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    3662         if kwargs:
# ...
